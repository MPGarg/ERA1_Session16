# %%
# !pip install transformers --quiet
# !pip install datasets --quiet
# !pip install torchmetrics --quiet
# !pip install tensorboard --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 60.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 98.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.4/763.4 kB 9.0 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/S16/S16")
# !ls
# Out:
# config.py   __pycache__		tokenizer_en.json  train.ipynb	  weights
# dataset.py  runs		tokenizer_fr.json  train.py
# model.py    speedXformer.ipynb	train1.py	   train.py.gdoc

# %%
import tensorboard

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 32
cfg['preload'] = True
cfg['num_epochs'] = 50

from train import train_model
import torch
torch.cuda.amp.autocast(enabled=True)

# %%
train_model(cfg)
# Out:
# Using device: cuda
# Downloading builder script:   0%|          | 0.00/6.08k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/161k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/20.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/127085 [00:00<?, ? examples/s]
# Max length of (filtered) source sentence: 45
# Max length of (filtered) target sentence: 48
# Preloading model weights/tmodel_24.pt
# preloaded
# Processing Epoch 25: 100%|██████████| 1912/1912 [02:47<00:00, 11.39it/s, loss=2.101]
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `CharErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `CharErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `WordErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `WordErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `BLEUScore` from `torchmetrics` was deprecated and will be removed in 2.0. Import `BLEUScore` from `torchmetrics.text` instead.
#   _future_warning(
# --------------------------------------------------------------------------------
#     SOURCE:  Well, perhaps a stone--"
#     TARGET: Eh bien, à coups de pierre alors...»
#  PREDICTED: Peut - être une pierre ...
# --------------------------------------------------------------------------------
#     SOURCE:  The point is settled, and I must refuse to argue upon it."
#     TARGET: C'est une affaire entendue et je dois me refuser à toute discussion sur ce point.
#  PREDICTED: Le point est convenu , et il faut que je vous de le faire .»
# --------------------------------------------------------------------------------
# Processing Epoch 26: 100%|██████████| 1912/1912 [02:49<00:00, 11.26it/s, loss=2.421]
# --------------------------------------------------------------------------------
#     SOURCE:  "No farinaceous or milk food, wear wool next the skin, and expose the diseased parts to the smoke of juniper berries."
#     TARGET: -- Pas de farineux ni de laitage! Porter de la laine sur la peau et exposer les parties malades à la fumée de baies de genièvre!
#  PREDICTED: -- Pas de ou de nourriture , à la chair de la peau , et à découvert le des affections détruites , des .
# --------------------------------------------------------------------------------
#     SOURCE:  Du moment ou je savais ou, les prendre ils étaient a ma merci.
#     TARGET: When once I found them out I knew that I had them at my mercy.
#  PREDICTED: When once I found them out I knew that I had them at my mercy .
# --------------------------------------------------------------------------------
# Processing Epoch 27: 100%|██████████| 1912/1912 [02:51<00:00, 11.12it/s, loss=1.837]
# --------------------------------------------------------------------------------
#     SOURCE:  By way of reply, his wife drew him aside and explained to him the necessity of getting rid of Julien.
#     TARGET: Pour toute réponse, sa femme le prit à part et lui exprima la nécessité d’éloigner Julien.
#  PREDICTED: À la suite , sa femme l ' entraîna à l ' écart et lui vinrent le tenir la nécessité d ' en .
# --------------------------------------------------------------------------------
#     SOURCE:  The bellringer allowed him to turn the corner of the street, then he ran after him with his ape−like agility, shouting: "Hey there! captain!"
#     TARGET: Le sonneur lui laissa doubler l’angle de la rue, puis il se mit à courir après lui avec son agilité de singe, en criant : « Hé ! le capitaine ! »
#  PREDICTED: Le sonneur lui laissa doubler l ’ angle de la rue , puis il courut après lui avec son agilité de singe , en criant : « Hé ! Le capitaine ! le capitaine !
# --------------------------------------------------------------------------------
# Processing Epoch 28: 100%|██████████| 1912/1912 [02:51<00:00, 11.16it/s, loss=2.344]
# --------------------------------------------------------------------------------
#     SOURCE:  "Fair cousin," he said, approaching Fleur−de−Lys, "what is the subject of this tapestry work which you are fashioning?' "Fair cousin," responded Fleur−de−Lys, in an offended tone, "I have already told you three times.
#     TARGET: « Belle cousine, dit-il en s’approchant de Fleur-de-Lys, quel est le sujet de cet ouvrage de tapisserie que vous façonnez ? – Beau cousin, répondit Fleur-de-Lys avec un accent de dépit, je vous l’ai déjà dit trois fois.
#  PREDICTED: – La Belle cousine , dit - il en s ’ approchant de Fleur - de - Lys , vraiment de cette tapisserie que vous êtes ?
# --------------------------------------------------------------------------------
#     SOURCE:  He felt contempt for both of them and treated them as slaves, telling them that he had a princess for his mistress and that they were unworthy to appear before her.
#     TARGET: Il les méprisait tous les deux, les traitait en esclaves, leur racontait qu'il avait pour maîtresse une princesse, devant laquelle ils étaient indignes de se montrer.
#  PREDICTED: Il leur sembla un mépris et les , les de , qu ' il avait une princesse dont ils étaient indigne auparavant .
# --------------------------------------------------------------------------------
# Processing Epoch 29: 100%|██████████| 1912/1912 [02:51<00:00, 11.13it/s, loss=1.991]
# --------------------------------------------------------------------------------
#     SOURCE:  Captain Nemo didn't stop studying the pressure gauge.
#     TARGET: Le capitaine Nemo ne cessait d'observer le manomètre.
#  PREDICTED: Le capitaine Nemo ne cessait de d ' observer le pression .
# --------------------------------------------------------------------------------
#     SOURCE:  The coal was giving out! "Ah, if my master can get over that," muttered he, "he'll be a famous man!"
#     TARGET: « Ah ! si mon maître pare celle-là, se dit-il, décidément ce sera un fameux homme ! »
#  PREDICTED: « Ah ! si mon maître se fait de monter sur ce « , » dit - il , il sera un fameux homme !
# --------------------------------------------------------------------------------
# Processing Epoch 30: 100%|██████████| 1912/1912 [02:52<00:00, 11.07it/s, loss=2.265]
# --------------------------------------------------------------------------------
#     SOURCE:  "In your soul?"
#     TARGET: – Dans l’âme ?
#  PREDICTED: – Dans votre âme .
# --------------------------------------------------------------------------------
#     SOURCE:  Then some words were spoken by the two women. At length the shutter closed.
#     TARGET: Puis, quelques mots furent prononcés entre les deux femmes.
#  PREDICTED: Puis , quelques mots furent prononcés entre les deux femmes .
# --------------------------------------------------------------------------------
# Processing Epoch 31: 100%|██████████| 1912/1912 [02:53<00:00, 11.02it/s, loss=1.736]
# --------------------------------------------------------------------------------
#     SOURCE:  Thanks, no doubt, to the willingness he showed, he had not to go down to the class below. But though he knew his rules passably, he had little finish in composition.
#     TARGET: Grâce, sans doute, à cette bonne volonté dont il fit preuve, il dut de ne pas descendre dans la classe inférieure; car, s’il savait passablement ses règles, il n’avait guère d’élégance dans les tournures.
#  PREDICTED: Sans doute , car il n ' avait que de sa volonté qu ' il n ' avait pas le descendre , au fond de cette petite couche , mais il savait sa couche sa couche son if il s ' appartenait
# --------------------------------------------------------------------------------
#     SOURCE:  So saying, with the dexterity of a monkey, he flung a bit of silver into the gray felt hat which the beggar held in his ailing arm.
#     TARGET: En parlant ainsi, il jetait avec une adresse de singe un petit-blanc dans le feutre gras que le mendiant tendait de son bras malade.
#  PREDICTED: Et , dit , le adresse d ' un singe , il jeta un bout d ' argent dans le chapeau gris ou la fosse malade , le malade
# --------------------------------------------------------------------------------
# Processing Epoch 32: 100%|██████████| 1912/1912 [02:52<00:00, 11.10it/s, loss=2.053]
# --------------------------------------------------------------------------------
#     SOURCE:  To-night, at least, I would be her guest, as I was her child: my mother would lodge me without money and without price.
#     TARGET: «Cette nuit-là, du moins, me dis-je serai son hôte comme je suis son enfant; ma mère me logera sans me demander le prix de son bienfait.»
#  PREDICTED: Ce soir - la , au moins , je serais son invité : ma mère trouvait l ’ enfant ; ma mère me sans prix .
# --------------------------------------------------------------------------------
#     SOURCE:  "Go, go," he said, "and good luck, or rather better luck."
#     TARGET: --Allez, allez, dit-il, et bonne chance, ou plutôt meilleure chance.
#  PREDICTED: « Allez , dit - il , et la chance me satisfait .
# --------------------------------------------------------------------------------
# Processing Epoch 33: 100%|██████████| 1912/1912 [02:52<00:00, 11.07it/s, loss=1.943]
# --------------------------------------------------------------------------------
#     SOURCE:  "I'm coming down, good God!"
#     TARGET: —Je descends, nom de Dieu!
#  PREDICTED: — Je descends , bonne !
# --------------------------------------------------------------------------------
#     SOURCE:  Nous espérons tous vous revoir un jour : rappelez-vous qu’il le faut.
#     TARGET: We all hope to see you again one day: remember that it is your duty.
#  PREDICTED: We all hope to see you again one day : remember that it is your duty .
# --------------------------------------------------------------------------------
# Processing Epoch 34: 100%|██████████| 1912/1912 [02:52<00:00, 11.07it/s, loss=2.336]
# --------------------------------------------------------------------------------
#     SOURCE:  "Poor little shoe!" said Oudarde.
#     TARGET: – Pauvre petit soulier ! » dit Oudarde.
#  PREDICTED: – Pauvre petite soulier ! dit Oudarde .
# --------------------------------------------------------------------------------
#     SOURCE:  Peut-être je vais tomber dans cette loge ; les fidèles réunis à la Visitation ne me verront point arriver, et demain, ils apprendront que leur futur archevêque s’est oublié dans une loge de l’Opéra, et encore, déguisé en domestique et couvert d’une livrée !
#     TARGET: Perhaps I am going to collapse in this box; the faithful gathered at the Visitation will wait for me in vain, and to-morrow they will learn that their future Archbishop forgot himself in a box at the Opera, and, what is more, disguised as a servant and wearing livery!
#  PREDICTED: Perhaps , I shall take us in this box at the box at the play so , and the right will be at the Archbishop ' s at the Archbishop ' s of the circumstances at the at the at the Archbishop and the Archbishop ' s room for the Archbishop ' s room for the Archbishop ' y at the police
# --------------------------------------------------------------------------------
# Processing Epoch 35: 100%|██████████| 1912/1912 [02:52<00:00, 11.06it/s, loss=2.317]
# --------------------------------------------------------------------------------
#     SOURCE:  We've feathered our nest; while one of these days you'll find the 'Cafe Francais' closed with a big placard on the shutters.
#     TARGET: Nous avons du foin dans nos bottes, nous autres! Au lieu qu’un de ces marins vous verrez le Café français fermé, et avec une belle affiche sur les auvents!...
#  PREDICTED: Nous avons de nos recherches . Pendant que vous verrez le haut du Français , le grand garçon du côté de la couche .
# --------------------------------------------------------------------------------
#     SOURCE:  This said in a carefree tone, Captain Nemo left the lounge.
#     TARGET: Cela dit d'un ton dégagé, le capitaine Nemo quitta le salon.
#  PREDICTED: Cela dit d ' un ton dégagé , le capitaine Nemo quitta le salon .
# --------------------------------------------------------------------------------
# Processing Epoch 36: 100%|██████████| 1912/1912 [02:52<00:00, 11.10it/s, loss=2.125]
# --------------------------------------------------------------------------------
#     SOURCE:  He thought that the clerk had perhaps seen her; but where did he live?
#     TARGET: Il pensa que le clerc peut-être l’avait vue; mais où demeurait-il?
#  PREDICTED: Il pensa que le clerc peut - être l ’ avait vue ; mais où demeurait - il ?
# --------------------------------------------------------------------------------
#     SOURCE:  "I hope so.
#     TARGET: -- Je l'espère bien.
#  PREDICTED: -- J ' espère .
# --------------------------------------------------------------------------------
# Processing Epoch 37: 100%|██████████| 1912/1912 [02:52<00:00, 11.12it/s, loss=1.812]
# --------------------------------------------------------------------------------
#     SOURCE:  It must be a sign of decadence ...'
#     TARGET: Ce sera un signe de décadence…
#  PREDICTED: Il faut un signe d ' esprit .
# --------------------------------------------------------------------------------
#     SOURCE:  How cruel, at that moment, those pleasantries seemed.
#     TARGET: Combien, en cet instant, ces plaisanteries lui paraissaient cruelles !
#  PREDICTED: Comment , cruel au moment , ces plaisanteries - là semblait .
# --------------------------------------------------------------------------------
# Processing Epoch 38: 100%|██████████| 1912/1912 [02:52<00:00, 11.07it/s, loss=1.910]
# --------------------------------------------------------------------------------
#     SOURCE:  "No, I don't blame you now."
#     TARGET: -- Non, je ne vous en veux plus!
#  PREDICTED: – Non , je ne vous en veux pas .
# --------------------------------------------------------------------------------
#     SOURCE:  _May_ 3.—I began with my saw, and cut a piece of a beam through, which I thought held some of the upper part or quarter-deck together, and when I had cut it through, I cleared away the sand as well as I could from the side which lay highest; but the tide coming in, I was obliged to give over for that time.
#     TARGET: Le 3.--Je commençai par scier un bau qui maintenait la partie supérieure proche le gaillard d'arrière, et, quand je l'eus coupé, j'ôtai tout ce que je pus du sable qui embarrassait la portion la plus élevée; mais, la marée venait à monter, je fus obligé de m'en tenir là pour cette fois.
#  PREDICTED: CHAPITRE III . Je avec moi , et une pièce de descendre par laquelle j ' avais cru remarquer à la partie des plus belle , et j ' avais dû occuper
# --------------------------------------------------------------------------------
# Processing Epoch 39: 100%|██████████| 1912/1912 [02:51<00:00, 11.14it/s, loss=1.950]
# --------------------------------------------------------------------------------
#     SOURCE:  Binet came in.
#     TARGET: Binet entra.
#  PREDICTED: Binet arriva .
# --------------------------------------------------------------------------------
#     SOURCE:  In the morning Milady, under the pretext that she had not slept well in the night and wanted rest, sent away the woman who attended her.
#     TARGET: Le matin, Milady, sous prétexte qu'elle n'avait pas dormi de la nuit et qu'elle avait besoin de repos, renvoya la femme qui veillait près d'elle.
#  PREDICTED: Le matin , Milady , sous prétexte qu ' elle ne dormait pas mal et eut voulu , elle renvoya la femme qui veillait près de la femme qui veillait près d ' elle
# --------------------------------------------------------------------------------
# Processing Epoch 40: 100%|██████████| 1912/1912 [02:51<00:00, 11.16it/s, loss=1.856]
# --------------------------------------------------------------------------------
#     SOURCE:  Elizabeth found the interest of the subject increase, and listened with all her heart; but the delicacy of it prevented further inquiry.
#     TARGET: Elizabeth de plus en plus intéressée ne perdait pas une seule de ces paroles, mais le sujet était trop délicat pour lui permettre de poser la moindre question.
#  PREDICTED: Elizabeth trouva le trouble de la soirée , et écoutait avec le cœur ; mais le métier de ce qu ’ il n ’ a plus question d ’ words
# --------------------------------------------------------------------------------
#     SOURCE:  These Americans refused to give up.
#     TARGET: Les Américains ne se découragèrent pas.
#  PREDICTED: Les Américains ne se pas
# --------------------------------------------------------------------------------
# Processing Epoch 41: 100%|██████████| 1912/1912 [02:53<00:00, 11.03it/s, loss=2.045]
# --------------------------------------------------------------------------------
#     SOURCE:  I might, if he were, with the aid of my own feeble wits, forecast what he would do or say.
#     TARGET: Je pourrais alors, à l’aide de ma faible raison, prévoir ce qu’il fera ou dira.
#  PREDICTED: J ' aurais pu , s ' il fût , avec l ' aide de mes faibles , on ou de ses fautes .
# --------------------------------------------------------------------------------
#     SOURCE:  Woman was created for our destruction, and it is from her we inherit all our miseries."
#     TARGET: La femme a été créée pour notre perte, et c'est d'elle que nous viennent toutes nos misères.»
#  PREDICTED: La femme a été créée pour notre perte , et c ' est d ' elle que nous viennent toutes nos misères .»
# --------------------------------------------------------------------------------
# Processing Epoch 42:  15%|█▌        | 290/1912 [00:26<02:35, 10.45it/s, loss=2.209]

# %%
tensorboard --logdir==runs
